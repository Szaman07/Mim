# %% [markdown]
# # 03 Evaluation & Offline Event Replay
#
# Evaluates detector checkpoints against validation/locked test splits and runs offline replay simulations through the deterministic event engine.

# %%
from scripts.run_event_replay import replay_event_stream

# Replay phone detection scenario
records = replay_event_stream(scenario="sustained_phone")
print(f"Emitted {len(records)} lifecycle event transitions.")

# %%
# Replay multi-person scenario
records_mp = replay_event_stream(scenario="multi_person")
print(f"Emitted {len(records_mp)} multi-person transitions.")

# %%
# Replay looking-away scenario
records_away = replay_event_stream(scenario="sustained_looking_away")
print(f"Emitted {len(records_away)} looking away transitions.")
